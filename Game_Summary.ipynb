# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 2/2, Home, Alls-Chatty, Brawls-BlueWhite
# 3/3, Away, Brawls-Cornfed, Brawls-BleedingHeartland, Brawls-RoyalCity
# 3/9, Home, Alls-BlackRose, Brawls-BlackRose
# 3/23, Away, Alls-TragicCity
# 4/6, Away, Alls-PennJersey
# 4/7, Away, Alls-Downriver, Alls-ForestCity
# 5/18, Away, Alls-ArchRival, Brawls-ArchRival
# 6/15, Away, Alls-BERG
# 6/16, Away, Alls-RedStick
# 7/13, Home, Alls-Fayetteville, Brawls-WindyCity
# 8/17, Home, Alls-ArchRival , Brawls-ArchRival
# 8/31, Away, Alls-Chatty, Brawls-Chatty

# %%
# 2/2, Home, Alls-Chatty, 
_0202Allspath = "0202Alls.csv"
_0202Alls_df = pd.read_csv(_0202Allspath, encoding="ISO-8859-1")

_0202Alls_df['Game Date'] = '020219'
_0202Alls_df['Team'] = 'Alls'
_0202Alls_df['Home/Away'] = 'Home'
_0202Alls_df['Opponent'] = 'Chatty'


# 3/3, Away, Brawls1-Cornfed, Brawls2-BleedingHeartland, Brawls3-RoyalCity
_03031Brawlspath = "0303-1-Brawls.csv"
_03031Brawls_df = pd.read_csv(_03031Brawlspath, encoding="ISO-8859-1")

_03031Brawls_df['Game Date'] = '030319'
_03031Brawls_df['Team'] = 'Brawls'
_03031Brawls_df['Home/Away'] = 'Away'
_03031Brawls_df['Opponent'] = 'Cornfed'


_03032Brawlspath = "0303-2-Brawls.csv"
_03032Brawls_df = pd.read_csv(_03032Brawlspath, encoding="ISO-8859-1")

_03032Brawls_df['Game Date'] = '030319'
_03032Brawls_df['Team'] = 'Brawls'
_03032Brawls_df['Home/Away'] = 'Away'
_03032Brawls_df['Opponent'] = 'BleedingHeartland'


_03033Brawlspath = "0303-3-Brawls.csv"
_03033Brawls_df = pd.read_csv(_03033Brawlspath, encoding="ISO-8859-1")

_03033Brawls_df['Game Date'] = '030319'
_03033Brawls_df['Team'] = 'Brawls'
_03033Brawls_df['Home/Away'] = 'Away'
_03033Brawls_df['Opponent'] = 'RoyalCity'


# 3/9, Home, Alls-BlackRose, Brawls-BlackRose
_0309Allspath = "0309Alls.csv"
_0309Alls_df = pd.read_csv(_0309Allspath, encoding="ISO-8859-1")

_0309Alls_df['Game Date'] = '030919'
_0309Alls_df['Team'] = 'Alls'
_0309Alls_df['Home/Away'] = 'Home'
_0309Alls_df['Opponent'] = 'BlackRose'


_0309Brawlspath = "0309Brawls.csv"
_0309Brawls_df = pd.read_csv(_0309Brawlspath, encoding="ISO-8859-1")

_0309Brawls_df['Game Date'] = '030919'
_0309Brawls_df['Team'] = 'Brawls'
_0309Brawls_df['Home/Away'] = 'Home'
_0309Brawls_df['Opponent'] = 'BlackRose'


# 3/23, Away, Alls-TragicCity
_0323Allspath = "0323Alls.csv"
_0323Alls_df = pd.read_csv(_0323Allspath, encoding="ISO-8859-1")

_0323Alls_df['Game Date'] = '032319'
_0323Alls_df['Team'] = 'Alls'
_0323Alls_df['Home/Away'] = 'Away'
_0323Alls_df['Opponent'] = 'TragicCity'


# 4/6, Away, Alls-PennJersey
_0406Allspath = "0406Alls.csv"
_0406Alls_df = pd.read_csv(_0406Allspath, encoding="ISO-8859-1")

_0406Alls_df['Game Date'] = '040619'
_0406Alls_df['Team'] = 'Alls'
_0406Alls_df['Home/Away'] = 'Away'
_0406Alls_df['Opponent'] = 'PennJersey'


# 4/7, Away, Alls-Downriver, Alls-ForestCity
_04071Allspath = "0407-1-Alls.csv"
_04071Alls_df = pd.read_csv(_04071Allspath, encoding="ISO-8859-1")

_04071Alls_df['Game Date'] = '040719'
_04071Alls_df['Team'] = 'Alls'
_04071Alls_df['Home/Away'] = 'Away'
_04071Alls_df['Opponent'] = 'DownRiver'

_04072Allspath = "0407-2-Alls.csv"
_04072Alls_df = pd.read_csv(_04072Allspath, encoding="ISO-8859-1")

_04072Alls_df['Game Date'] = '040719'
_04072Alls_df['Team'] = 'Alls'
_04072Alls_df['Home/Away'] = 'Away'
_04072Alls_df['Opponent'] = 'ForestCity'


# 5/18, Away, Alls-ArchRival, Brawls-ArchRival
_0518Allspath = "0518Alls.csv"
_0518Alls_df = pd.read_csv(_0518Allspath, encoding="ISO-8859-1")

_0518Alls_df['Game Date'] = '051819'
_0518Alls_df['Team'] = 'Alls'
_0518Alls_df['Home/Away'] = 'Away'
_0518Alls_df['Opponent'] = 'ArchRival'


_0518Brawlspath = "0518Brawls.csv"
_0518Brawls_df = pd.read_csv(_0518Brawlspath, encoding="ISO-8859-1")

_0518Brawls_df['Game Date'] = '051819'
_0518Brawls_df['Team'] = 'Brawls'
_0518Brawls_df['Home/Away'] = 'Away'
_0518Brawls_df['Opponent'] = 'ArchRival'


# 6/15, Away, Alls-BERG
_0615Allspath = "0615Alls.csv"
_0615Alls_df = pd.read_csv(_0615Allspath, encoding="ISO-8859-1")

_0615Alls_df['Game Date'] = '061519'
_0615Alls_df['Team'] = 'Alls'
_0615Alls_df['Home/Away'] = 'Away'
_0615Alls_df['Opponent'] = 'BERG'


# 6/16, Away, Alls-RedStick
_0616Allspath = "0616Alls.csv"
_0616Alls_df = pd.read_csv(_0616Allspath, encoding="ISO-8859-1")

_0616Alls_df['Game Date'] = '061619'
_0616Alls_df['Team'] = 'Alls'
_0616Alls_df['Home/Away'] = 'Away'
_0616Alls_df['Opponent'] = 'RedStick'



# 7/13, Home, Alls-Fayetteville, Brawls-WindyCity
_0713Allspath = "0713Alls.csv"
_0713Alls_df = pd.read_csv(_0713Allspath, encoding="ISO-8859-1")

_0713Alls_df['Game Date'] = '071319'
_0713Alls_df['Team'] = 'Alls'
_0713Alls_df['Home/Away'] = 'Home'
_0713Alls_df['Opponent'] = 'Fayetteville'


_0713Brawlspath = "0713Brawls.csv"
_0713Brawls_df = pd.read_csv(_0713Brawlspath, encoding="ISO-8859-1")

_0713Brawls_df['Game Date'] = '071319'
_0713Brawls_df['Team'] = 'Brawls'
_0713Brawls_df['Home/Away'] = 'Home'
_0713Brawls_df['Opponent'] = 'WindyCity'



# 8/17, Home, Alls-ArchRival , Brawls-ArchRival
_0817Allspath = "0817Alls.csv"
_0817Alls_df = pd.read_csv(_0817Allspath, encoding="ISO-8859-1")

_0817Alls_df['Game Date'] = '081719'
_0817Alls_df['Team'] = 'Alls'
_0817Alls_df['Home/Away'] = 'Home'
_0817Alls_df['Opponent'] = 'ArchRival'


_0817Brawlspath = "0817Brawls.csv"
_0817Brawls_df = pd.read_csv(_0817Brawlspath, encoding="ISO-8859-1")

_0817Brawls_df['Game Date'] = '081719'
_0817Brawls_df['Team'] = 'Brawls'
_0817Brawls_df['Home/Away'] = 'Home'
_0817Brawls_df['Opponent'] = 'ArchRival'



# 8/31, Away, Alls-Chatty, Brawls-Chatty

# %%
# Way oversimplifying everything, but I can throw them all together and then add everything up
# This would only be useful for the data in this set that can be summarized (like the number of times as jammer, total points, etc. )

home_away_counts = pd.concat([_0202Alls_df,  _03031Brawls_df, _03032Brawls_df, _03033Brawls_df, _0309Alls_df, _0309Brawls_df, _0323Alls_df, _0406Alls_df, _04071Alls_df, _04072Alls_df, _0518Alls_df, _0518Brawls_df, _0615Alls_df, _0616Alls_df, _0713Alls_df, _0713Brawls_df, _0817Alls_df, _0817Brawls_df]).groupby(['#']).sum().reset_index()
home_away_counts
# Out:
#                  #  JAMMER  PIVOT  BLOCKER  TOTAL  POINTS    PPJ  LOST  LEAD  \
# 0                7   130.0    0.0      5.0  131.0   398.0  33.52  10.0  66.0
# 1               11     0.0    0.0     10.0   10.0     0.0   0.00   0.0   0.0
# 2               13    14.0   17.0     57.0   87.0    26.0   2.60   0.0   2.0
# 3               14    27.0    3.0     25.0   54.0    53.0   8.67   5.0   7.0
# 4               18     0.0    0.0    250.0  250.0     0.0   0.00   0.0   0.0
# 5               23     3.0  108.0    105.0  213.0     8.0   4.00   0.0   0.0
# 6               27     0.0    0.0     27.0   27.0     0.0   0.00   0.0   0.0
# 7               31    69.0   14.0      7.0   90.0   291.0  23.79   8.0  42.0
# 8               42     0.0    0.0    160.0  160.0     0.0   0.00   0.0   0.0
# 9               43   130.0    1.0      1.0  131.0   740.0  58.63   7.0  77.0
# 10              53   145.0   31.0      6.0  175.0   568.0  42.58  15.0  82.0
# 11              57     0.0    1.0    144.0  145.0     0.0   0.00   0.0   0.0
# 12              64     0.0   11.0     74.0   85.0     0.0   0.00   0.0   0.0
# 13              77     3.0   26.0     41.0   67.0     1.0   0.33   0.0   0.0
# 14              79    44.0    0.0      3.0   44.0   123.0  14.68   4.0  20.0
# 15              86     3.0   35.0     72.0  107.0     2.0   0.67   0.0   0.0
# 16              90     0.0    1.0     16.0   17.0     0.0   0.00   0.0   0.0
# 17              97     0.0    0.0     45.0   45.0     0.0   0.00   0.0   0.0
# 18             121     3.0  102.0    189.0  291.0     4.0   1.33   0.0   0.0
# 19             124     0.0    1.0    229.0  230.0     0.0   0.00   0.0   0.0
# 20             187     0.0    0.0     42.0   42.0     0.0   0.00   0.0   0.0
# 21             220    10.0  223.0     70.0  293.0     4.0   2.00   0.0   0.0
# 22             329    23.0   59.0    253.0  328.0    72.0  11.78   1.0   7.0
# 23             369     0.0    0.0     14.0   14.0     0.0   0.00   0.0   0.0
# 24             404    22.0   16.0     30.0   66.0    84.0  11.20   2.0   6.0
# 25             454     0.0    0.0      2.0    2.0     0.0   0.00   0.0   0.0
# 26             548     6.0   92.0     38.0  130.0    18.0   9.00   0.0   0.0
# 27             671    75.0    0.0      7.0   79.0   293.0  31.72  13.0  36.0
# 28             762     0.0    0.0     16.0   16.0     0.0   0.00   0.0   0.0
# 29             777    26.0    2.0     76.0  104.0    99.0  13.04   8.0  10.0
# 30             815     0.0    0.0     15.0   15.0     0.0   0.00   0.0   0.0
# 31             911     0.0    0.0     61.0   61.0     0.0   0.00   0.0   0.0
# 32             927    29.0    4.0     94.0  125.0   143.0  20.60   8.0  19.0
# 33            1130     0.0    0.0     39.0   39.0     0.0   0.00   0.0   0.0
# 34            2586     0.0    0.0     32.0   32.0     0.0   0.00   0.0   0.0
# 35            3019    23.0    0.0     16.0   39.0    40.0   3.42   1.0  12.0
# 36              14     9.0    7.0      1.0   16.0     8.0   0.89   0.0   3.0
# 37             187     0.0    0.0      9.0    9.0     0.0   0.00   0.0   0.0
# 38            3019     4.0    4.0      5.0   13.0     3.0   0.75   0.0   1.0
# 39             369     0.0    0.0     10.0   10.0     0.0   0.00   0.0   0.0
# 40              48     0.0    0.0     10.0   10.0     0.0   0.00   0.0   0.0
# 41             548     1.0   23.0      1.0   23.0    12.0  12.00   0.0   0.0
# 42             671     5.0   13.0      1.0   19.0     6.0   1.20   0.0   2.0
# 43              77     0.0    0.0     25.0   25.0     0.0   0.00   0.0   0.0
# 44             777    14.0    0.0      0.0   13.0    38.0   2.71   2.0   7.0
# 45              79    12.0    0.0      0.0   12.0    31.0   2.58   0.0   4.0
# 46             815     0.0    0.0      6.0    6.0     0.0   0.00   0.0   0.0
# 47              86     6.0    0.0     14.0   20.0     7.0   1.17   0.0   2.0
# 48             911     0.0    1.0     25.0   26.0     0.0   0.00   0.0   0.0
# 49             927     0.0    1.0     25.0   26.0     0.0   0.00   0.0   0.0
# 50              97     0.0    0.0     17.0   17.0     0.0   0.00   0.0   0.0
# 51  TEAM SUMMARIES    51.0   49.0    149.0  245.0   105.0   2.14   2.0  19.0
#
#     CALLED  ...  AVG +/-  VTAR PTS FOR  VTAR  PTS AGAINST  VTAR  TOTAL +/-  \
# 0     57.0  ...     0.73        -317.5             -218.8            -98.6
# 1      0.0  ...     1.90         -23.3               -7.4            -15.9
# 2      1.0  ...    -3.51         -54.2               -6.9            -47.1
# 3      4.0  ...   -11.11        -168.5              -91.6            -76.4
# 4      0.0  ...    11.42         230.7               59.7            171.4
# 5      0.0  ...     7.17         260.3              248.7             11.6
# 6      0.0  ...    -6.28         -96.1             -122.0             26.2
# 7     34.0  ...     9.03         -38.5                2.1            -40.5
# 8      0.0  ...    -6.95        -206.5               66.3           -272.7
# 9     65.0  ...    33.69          44.2             -154.5            198.9
# 10    67.0  ...    11.27         -67.2              -54.1            -12.9
# 11     0.0  ...     4.28         110.2               49.9             60.2
# 12     0.0  ...     4.55        -286.4             -137.2           -149.1
# 13     0.0  ...     0.52         116.6               91.3             25.5
# 14    16.0  ...    -8.43        -185.5             -159.6            -25.4
# 15     0.0  ...     1.92         100.5               77.4             23.6
# 16     0.0  ...     3.82          38.7                8.6             30.1
# 17     0.0  ...    -1.74         -93.1              -10.0            -82.8
# 18     0.0  ...     0.68         220.4              352.4           -131.5
# 19     0.0  ...    10.41         202.5              129.3             73.4
# 20     0.0  ...     1.74          28.8               13.0             16.0
# 21     0.0  ...     7.17         448.5              309.3            139.3
# 22     6.0  ...     9.61         436.4              262.4            174.5
# 23     0.0  ...     4.55         -50.2              -59.0              9.0
# 24     3.0  ...     2.82          61.4               53.4              8.4
# 25     0.0  ...    -8.00         -24.2              -51.7             27.5
# 26     0.0  ...     1.27         209.5              204.4              5.6
# 27    27.0  ...   -18.64        -163.0             -222.9             60.4
# 28     0.0  ...    -2.00         -42.9              -48.0              5.2
# 29     4.0  ...     0.92        -122.6              -84.0            -38.0
# 30     0.0  ...    -9.57         -46.9              -21.0            -25.8
# 31     0.0  ...    -9.53        -109.9             -105.7             -4.0
# 32    12.0  ...    -6.80        -237.0             -221.1            -15.4
# 33     0.0  ...     0.52        -102.6              -66.6            -35.6
# 34     0.0  ...    -2.12          54.6               43.4             11.4
# 35    11.0  ...   -11.40        -128.8             -127.3             -1.1
# 36     2.0  ...    -2.69          -8.0               -9.3              1.3
# 37     0.0  ...    -2.78         -29.0              -48.3             19.3
# 38     1.0  ...    -2.15         -22.0              -38.3             16.3
# 39     0.0  ...     0.30         -12.0              -59.3             47.3
# 40     0.0  ...    -1.60           1.0              -27.3             28.3
# 41     0.0  ...    -4.00          25.0               72.7            -47.7
# 42     2.0  ...    -1.58           3.0              -11.3             14.3
# 43     0.0  ...    -3.32          16.0               54.7            -38.7
# 44     5.0  ...    -3.31           3.0                1.7              1.3
# 45     3.0  ...    -3.42          -4.0               -7.3              3.3
# 46     0.0  ...    -2.33         -27.0              -57.3             30.3
# 47     2.0  ...    -1.80           1.0               -7.3              8.3
# 48     0.0  ...    -3.46          33.0               78.7            -45.7
# 49     0.0  ...    -1.50          13.0                7.7              5.3
# 50     0.0  ...    -5.18           7.0               50.7            -43.7
# 51    15.0  ...    -3.00           0.0                0.0              0.0
#
#     VTAR JAMMER AVG +/-  VTAR PIVOT AVG +/-  VTAR BLOCKER AVG +/-  \
# 0                  0.41                0.00                  8.30
# 1                  0.00                0.00                 -0.52
# 2                 -7.75                1.88                 -5.15
# 3                -12.48               -4.93                 -3.85
# 4                  0.00                0.00                  9.24
# 5                 -0.71                3.30                  0.75
# 6                  0.00                0.00                  0.76
# 7                  1.49               -4.80                 -0.54
# 8                  0.00                0.00                -11.40
# 9                 25.21               -4.67                  8.26
# 10                 0.53                7.12                 -0.06
# 11                 0.00                0.92                  1.93
# 12                 0.00                3.82                 -1.23
# 13                 2.83               -4.28                  3.94
# 14               -10.72                0.00                 13.86
# 15                 3.17                2.43                 -7.30
# 16                 0.00               -0.08                  1.52
# 17                 0.00                0.00                 -0.51
# 18                 5.17               -9.27                  4.26
# 19                 0.00               12.44                  5.26
# 20                 0.00                0.00                  1.21
# 21                -8.62               -2.82                 -6.10
# 22                 9.92               -8.78                  0.22
# 23                 0.00                0.00                  4.01
# 24               -14.11                4.24                 12.08
# 25                 0.00                0.00                 -3.28
# 26                14.24                2.58                 -3.07
# 27                -7.84                0.00                 -7.09
# 28                 0.00                0.00                  2.69
# 29                -2.90               -3.76                  3.91
# 30                 0.00                0.00                 -4.88
# 31                 0.00                0.00                 -7.17
# 32                 2.66                4.65                -11.54
# 33                 0.00                0.00                 -0.12
# 34                 0.00                0.00                  0.68
# 35                -0.43                0.00                 -9.03
# 36                 0.56               -3.45                  6.18
# 37                 0.00                0.00                 -0.59
# 38                -1.71                1.20                 -0.22
# 39                 0.00                0.00                  2.48
# 40                 0.00                0.00                  0.58
# 41                 5.79               -2.30                 -1.82
# 42                -2.01                1.16                 -1.82
# 43                 0.00                0.00                 -1.14
# 44                -1.28                0.00                  0.00
# 45                -1.63                0.00                  0.00
# 46                 0.00                0.00                 -0.15
# 47                 0.29                0.00                  0.26
# 48                 0.00               -2.30                 -1.26
# 49                 0.00                5.70                  0.46
# 50                 0.00                0.00                 -2.99
# 51                 0.00                0.00                  0.00
#
#     VTAR PACK\nAVG +/-  TOTAL VTAR AVG +/-  SKATERS PENALTY COUNT
# 0                 8.85               -2.69                   25.0
# 1                -0.50               -0.52                    6.0
# 2                -2.80               -4.89                   11.0
# 3                -5.16               -8.81                   15.0
# 4                 9.07               10.62                   31.0
# 5                -0.63                0.11                   48.0
# 6                -0.54                0.05                    1.0
# 7                 0.34               -0.49                   23.0
# 8               -11.98              -10.37                   27.0
# 9                 3.53               22.94                   19.0
# 10                0.94                3.84                   36.0
# 11                2.20                3.87                   25.0
# 12               -1.18               -2.00                   10.0
# 13                3.17                2.62                   11.0
# 14               14.24               -6.13                    9.0
# 15                4.74                4.21                   25.0
# 16                1.43                1.40                    0.0
# 17               -1.85               -3.67                    2.0
# 18               -3.92               -2.55                   50.0
# 19                5.43                6.98                   42.0
# 20                0.54                0.43                    4.0
# 21                3.65                3.73                   41.0
# 22               -2.01                6.40                   39.0
# 23                3.35                3.24                    2.0
# 24                8.07                1.72                   13.0
# 25               -4.12               -4.59                    0.0
# 26                3.42                3.57                    4.0
# 27               -6.59               -9.65                   18.0
# 28                1.88                1.41                    1.0
# 29                3.07                2.89                   31.0
# 30               -5.69               -6.15                    1.0
# 31               -8.93               -8.11                    9.0
# 32              -12.13               -5.89                   30.0
# 33               -0.42               -0.58                    4.0
# 34                0.92                2.10                   14.0
# 35              -10.34               -5.08                    5.0
# 36               -1.53               -0.10                    1.0
# 37               -0.31               -0.19                    2.0
# 38                0.92                0.43                    1.0
# 39                2.77                2.89                    0.0
# 40                0.87                0.99                    4.0
# 41               -1.53               -1.41                    0.0
# 42                1.69                1.01                    1.0
# 43               -0.85               -0.73                    6.0
# 44                0.00               -0.72                    6.0
# 45                0.00               -0.83                    2.0
# 46                0.14                0.25                    0.0
# 47                0.54                0.79                    2.0
# 48               -0.99               -0.87                    4.0
# 49                0.97                1.09                    4.0
# 50               -2.70               -2.59                    2.0
# 51                0.00                0.00                   35.0
#
# [52 rows x 35 columns]

# %%
home_away = home_away_counts[['#', 'JAMMER', 'PIVOT', 'BLOCKER', 'POINTS', 'LOST', 'LEAD', 'CALLED', 'NO INITIAL TRIP', 'STAR PASSES RECEIVED', 'PTS  FOR', 'PTS AGAINST', 'JAMMER +/-', 'PIVOT +/-', 'BLOCK +/-', 'SKATERS PENALTY COUNT']]

# %%
home_away
home_away.to_csv("2019_Home_Away_Games_Alls-and-Brawls-3.csv")

# %%
all_df = pd.concat([_0202Alls_df,  _03031Brawls_df, _03032Brawls_df, _03033Brawls_df, _0309Alls_df, _0309Brawls_df, _0323Alls_df, _0406Alls_df, _04071Alls_df, _04072Alls_df, _0518Alls_df, _0518Brawls_df, _0615Alls_df, _0616Alls_df, _0713Alls_df, _0713Brawls_df, _0817Alls_df, _0817Brawls_df])
all_df.head()
# Out:
#      #             Skater  JAMMER  PIVOT  BLOCKER  TOTAL %  JAMS SKATED  \
# 0   11  Polly Pushy Pants     0.0    0.0     10.0   10.0            23%
# 1   13      Surely Mental     3.0    0.0      3.0    6.0            14%
# 2   23           Sintilly     0.0   14.0      7.0   21.0            49%
# 3  124        Ka-Blamazon     0.0    0.0     16.0   16.0            37%
# 4   31            Poptart    14.0    0.0      0.0   14.0            33%
#
#    POINTS   PPJ  LOST  ...  VTAR JAMMER AVG +/-  VTAR PIVOT AVG +/-  \
# 0     NaN   NaN   NaN  ...                  NaN                 NaN
# 1     0.0  0.00   0.0  ...                -4.66                 NaN
# 2     NaN   NaN   NaN  ...                  NaN                 2.7
# 3     NaN   NaN   NaN  ...                  NaN                 NaN
# 4   102.0  7.29   2.0  ...                 3.65                 NaN
#
#    VTAR BLOCKER AVG +/-  VTAR PACK\nAVG +/- TOTAL VTAR AVG +/-  \
# 0                 -0.52               -0.50              -0.52
# 1                  0.92                0.94              -2.59
# 2                  0.16                1.65               1.63
# 3                  1.71                1.73               1.70
# 4                   NaN                 NaN               2.22
#
#    SKATERS PENALTY COUNT  Game Date  Team  Home/Away  Opponent
# 0                    6.0     020219  Alls       Home    Chatty
# 1                    0.0     020219  Alls       Home    Chatty
# 2                    5.0     020219  Alls       Home    Chatty
# 3                    3.0     020219  Alls       Home    Chatty
# 4                    3.0     020219  Alls       Home    Chatty
#
# [5 rows x 42 columns]

# %%
skaters = all_df[['#', 'Skater', 'Team', 'Game Date']]
u_skaters = skaters['#'].unique()

alls = skaters.loc[skaters['Team']=='Alls']
brawls = skaters.loc[skaters['Team']=='Brawls']

a_game_count = alls['Game Date'].count()
b_game_count = brawls['Game Date'].count()


total_games = skaters.groupby(['#']).count()

test = skaters.groupby(['#']).size()

alls.to_csv('alls.csv')
brawls.to_csv('brawls.csv')

# %%
skaters_summary = all_df[['#', 'Skater', 'JAMMER', 'PIVOT', 'BLOCKER', 'Team']]
skaters_summary.to_csv('skaters.csv')
