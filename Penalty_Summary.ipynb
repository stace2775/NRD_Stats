# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 2/2, Home, Alls-Chatty, 
_0202Allspath = "0202Alls_PS.csv"
_0202Alls_df = pd.read_csv(_0202Allspath, encoding="ISO-8859-1")

_0202Alls_df['Game Date'] = '020219'
_0202Alls_df['Team'] = 'Alls'
_0202Alls_df['Home/Away'] = 'Home'
_0202Alls_df['Opponent'] = 'Chatty'


# 3/3, Away, Brawls1-Cornfed, Brawls2-BleedingHeartland, Brawls3-RoyalCity
_03031Brawlspath = "0303-1-Brawls_PS.csv"
_03031Brawls_df = pd.read_csv(_03031Brawlspath, encoding="ISO-8859-1")

_03031Brawls_df['Game Date'] = '030319'
_03031Brawls_df['Team'] = 'Brawls'
_03031Brawls_df['Home/Away'] = 'Away'
_03031Brawls_df['Opponent'] = 'Cornfed'


_03032Brawlspath = "0303-2-Brawls_PS.csv"
_03032Brawls_df = pd.read_csv(_03032Brawlspath, encoding="ISO-8859-1")

_03032Brawls_df['Game Date'] = '030319'
_03032Brawls_df['Team'] = 'Brawls'
_03032Brawls_df['Home/Away'] = 'Away'
_03032Brawls_df['Opponent'] = 'BleedingHeartland'


_03033Brawlspath = "0303-3-Brawls_PS.csv"
_03033Brawls_df = pd.read_csv(_03033Brawlspath, encoding="ISO-8859-1")

_03033Brawls_df['Game Date'] = '030319'
_03033Brawls_df['Team'] = 'Brawls'
_03033Brawls_df['Home/Away'] = 'Away'
_03033Brawls_df['Opponent'] = 'RoyalCity'


# 3/9, Home, Alls-BlackRose, Brawls-BlackRose
_0309Allspath = "0309Alls_PS.csv"
_0309Alls_df = pd.read_csv(_0309Allspath, encoding="ISO-8859-1")

_0309Alls_df['Game Date'] = '030919'
_0309Alls_df['Team'] = 'Alls'
_0309Alls_df['Home/Away'] = 'Home'
_0309Alls_df['Opponent'] = 'BlackRose'


_0309Brawlspath = "0309Brawls_PS.csv"
_0309Brawls_df = pd.read_csv(_0309Brawlspath, encoding="ISO-8859-1")

_0309Brawls_df['Game Date'] = '030919'
_0309Brawls_df['Team'] = 'Brawls'
_0309Brawls_df['Home/Away'] = 'Home'
_0309Brawls_df['Opponent'] = 'BlackRose'


# 3/23, Away, Alls-TragicCity
_0323Allspath = "0323Alls_PS.csv"
_0323Alls_df = pd.read_csv(_0323Allspath, encoding="ISO-8859-1")

_0323Alls_df['Game Date'] = '032319'
_0323Alls_df['Team'] = 'Alls'
_0323Alls_df['Home/Away'] = 'Away'
_0323Alls_df['Opponent'] = 'TragicCity'


# 4/6, Away, Alls-PennJersey
_0406Allspath = "0406Alls_PS.csv"
_0406Alls_df = pd.read_csv(_0406Allspath, encoding="ISO-8859-1")

_0406Alls_df['Game Date'] = '040619'
_0406Alls_df['Team'] = 'Alls'
_0406Alls_df['Home/Away'] = 'Away'
_0406Alls_df['Opponent'] = 'PennJersey'


# 4/7, Away, Alls-Downriver, Alls-ForestCity
_04071Allspath = "0407-1-Alls_PS.csv"
_04071Alls_df = pd.read_csv(_04071Allspath, encoding="ISO-8859-1")

_04071Alls_df['Game Date'] = '040719'
_04071Alls_df['Team'] = 'Alls'
_04071Alls_df['Home/Away'] = 'Away'
_04071Alls_df['Opponent'] = 'DownRiver'

_04072Allspath = "0407-2-Alls_PS.csv"
_04072Alls_df = pd.read_csv(_04072Allspath, encoding="ISO-8859-1")

_04072Alls_df['Game Date'] = '040719'
_04072Alls_df['Team'] = 'Alls'
_04072Alls_df['Home/Away'] = 'Away'
_04072Alls_df['Opponent'] = 'ForestCity'


# 5/18, Away, Alls-ArchRival, Brawls-ArchRival
_0518Allspath = "0518Alls_PS.csv"
_0518Alls_df = pd.read_csv(_0518Allspath, encoding="ISO-8859-1")

_0518Alls_df['Game Date'] = '051819'
_0518Alls_df['Team'] = 'Alls'
_0518Alls_df['Home/Away'] = 'Away'
_0518Alls_df['Opponent'] = 'ArchRival'


_0518Brawlspath = "0518Brawls_PS.csv"
_0518Brawls_df = pd.read_csv(_0518Brawlspath, encoding="ISO-8859-1")

_0518Brawls_df['Game Date'] = '051819'
_0518Brawls_df['Team'] = 'Brawls'
_0518Brawls_df['Home/Away'] = 'Away'
_0518Brawls_df['Opponent'] = 'ArchRival'


# 6/15, Away, Alls-BERG
_0615Allspath = "0615Alls_PS.csv"
_0615Alls_df = pd.read_csv(_0615Allspath, encoding="ISO-8859-1")

_0615Alls_df['Game Date'] = '061519'
_0615Alls_df['Team'] = 'Alls'
_0615Alls_df['Home/Away'] = 'Away'
_0615Alls_df['Opponent'] = 'BERG'


# 6/16, Away, Alls-RedStick
_0616Allspath = "0616Alls_PS.csv"
_0616Alls_df = pd.read_csv(_0616Allspath, encoding="ISO-8859-1")

_0616Alls_df['Game Date'] = '061619'
_0616Alls_df['Team'] = 'Alls'
_0616Alls_df['Home/Away'] = 'Away'
_0616Alls_df['Opponent'] = 'RedStick'



# 7/13, Home, Alls-Fayetteville, Brawls-WindyCity
_0713Allspath = "0713Alls_PS.csv"
_0713Alls_df = pd.read_csv(_0713Allspath, encoding="ISO-8859-1")

_0713Alls_df['Game Date'] = '071319'
_0713Alls_df['Team'] = 'Alls'
_0713Alls_df['Home/Away'] = 'Home'
_0713Alls_df['Opponent'] = 'Fayetteville'


_0713Brawlspath = "0713Brawls_PS.csv"
_0713Brawls_df = pd.read_csv(_0713Brawlspath, encoding="ISO-8859-1")

_0713Brawls_df['Game Date'] = '071319'
_0713Brawls_df['Team'] = 'Brawls'
_0713Brawls_df['Home/Away'] = 'Home'
_0713Brawls_df['Opponent'] = 'WindyCity'



# 8/17, Home, Alls-ArchRival , Brawls-ArchRival
# 8/31, Away, Alls-Chatty, Brawls-Chatty

# %%
home_away_counts = pd.concat([_0202Alls_df,  _03031Brawls_df, _03032Brawls_df, _03033Brawls_df, _0309Alls_df, _0309Brawls_df, _0323Alls_df, _0406Alls_df, _04071Alls_df, _04072Alls_df, _0518Alls_df, _0518Brawls_df, _0615Alls_df, _0616Alls_df, _0713Alls_df, _0713Brawls_df]).groupby(['#']).sum().reset_index()

#del home_away_counts['Unnamed: 2']
#del home_away_counts['Unnamed: 17']
#del home_away_counts['Unnamed: 18']

home_away_counts.columns
# Out:
# Index(['#', 'Unnamed: 2', 'Misconduct', 'High Block', 'Back Block',
#        'Low Block', 'Leg Block', 'Forearms', 'Head Block', 'Multiplayer',
#        'Illegal Contact', 'Direction', 'Illegal Position', 'Cut',
#        'Interference', 'Illegal Procedure', 'Unnamed: 17', 'Unnamed: 18',
#        'TOTAL ', 'Penalty Count', 'Expulsion', 'Jams Skated'],
#       dtype='object')

# %%
#home_away_counts.to_csv("Penalty_Summary_2019_Home_Away_Games_Alls-and-Brawls-1.csv")

# %%
misconduct = home_away_counts['Misconduct'].sum()
high_block = home_away_counts['High Block'].sum()
back_block = home_away_counts['Back Block'].sum()
low_block = home_away_counts['Low Block'].sum()
leg_block = home_away_counts['Leg Block'].sum()
forearms = home_away_counts['Forearms'].sum()
head_block = home_away_counts['Head Block'].sum()
multiplayer = home_away_counts['Multiplayer'].sum()
illegal_contact = home_away_counts['Illegal Contact'].sum()
direction = home_away_counts['Direction'].sum()
illegal_position = home_away_counts['Illegal Position'].sum()
cut = home_away_counts['Cut'].sum()
interference = home_away_counts['Interference'].sum()
illegal_procedure = home_away_counts['Illegal Procedure'].sum()
expulsion = home_away_counts['Expulsion'].sum()


p_sums = pd.DataFrame({
    'Misconduct': [misconduct],
    'High Block': [high_block],
    'Back Block': [back_block],
    'Low Block': [low_block],
    'Leg Block': [leg_block],
    'Forearms': [forearms],
    'Head Block': [head_block],
    'Multiplayer': [multiplayer],
    'Illegal Contact': [illegal_contact],
    'Direction': [direction],
    'Illegal Position': [illegal_position],
    'Cut': [cut],
    'Interference': [interference],
    'Illegal Procedure':[illegal_procedure],
    'Expulsion': [expulsion]


})

p_sums_df = p_sums.transpose()
p_sums_n = p_sums_df.reset_index()
p_sums_n = p_sums_n.rename(columns = {'index': 'penalty', 0: 'count'})
p_sums_c = p_sums_n.sort_values('count')

# %%
#Bar chart
penalty = p_sums_c['penalty']
count = p_sums_c['count']
x_axis = np.arange(len(penalty))



plt.bar(x_axis, count, color='blue', alpha=0.5, align='center')
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, penalty, rotation="vertical")

plt.title("Penalty Counts - Alls & Brawls 2019")
plt.xlabel("Penalty")
plt.ylabel("Penalty Count")

plt.savefig("Penalty Counts - Alls & Brawls 2019.png", bbox_inches="tight")

# %%
penalties = pd.concat([_0202Alls_df,  _03031Brawls_df, _03032Brawls_df, _03033Brawls_df, _0309Alls_df, _0309Brawls_df, _0323Alls_df, _0406Alls_df, _04071Alls_df, _04072Alls_df, _0518Alls_df, _0518Brawls_df, _0615Alls_df, _0616Alls_df, _0713Alls_df, _0713Brawls_df])
#alls = penalties.loc[(penalties['Team']=='Alls') | (penalties['Team']=='All')].sum()
#brawls = penalties.loc[penalties['Team']=='Brawls'].sum()

pppath = "penalties_position.csv"
pp_df = pd.read_csv(pppath, encoding="ISO-8859-1")
pp_df

alls = pp_df.loc[pp_df['Team']=='All']
brawls = pp_df.loc[pp_df['Team']=='Brawl']


brawls_ppj = brawls['Penalty Count']/brawls['Jams Skated']
brawls_ppj

alls_ppj = alls['Penalty Count']/alls['Jams Skated']

totals = pp_df.sum()


brawls.sum()
# Out:
# #                                                                  10702
# Team                   BrawlBrawlBrawlBrawlBrawlBrawlBrawlBrawlBrawlB...
# JAMMER (# of Jams)                                                   126
# PIVOT (# of Jams)                                                    189
# BLOCKER (# of Jams)                                                  465
# Misconduct                                                             2
# High Block                                                             5
# Back Block                                                             5
# Low Block                                                              1
# Leg Block                                                              0
# Forearms                                                              21
# Head Block                                                             0
# Multiplayer                                                           16
# ...

# %%
#OVERALL ALLS PENALTIES

a_misconduct = alls['Misconduct'].sum()
a_high_block = alls['High Block'].sum()
a_back_block = alls['Back Block'].sum()
a_low_block = alls['Low Block'].sum()
a_leg_block = alls['Leg Block'].sum()
a_forearms = alls['Forearms'].sum()
a_head_block = alls['Head Block'].sum()
a_multiplayer = alls['Multiplayer'].sum()
a_illegal_contact = alls['Illegal Contact'].sum()
a_direction = alls['Direction'].sum()
a_illegal_position = alls['Illegal Position'].sum()
a_cut = alls['Cut'].sum()
a_interference = alls['Interference'].sum()
a_illegal_procedure = alls['Illegal Procedure'].sum()
a_expulsion = alls['Expulsion'].sum()


a_sums = pd.DataFrame({
    'Misconduct': [a_misconduct],
    'High Block': [a_high_block],
    'Back Block': [a_back_block],
    'Low Block': [a_low_block],
    'Leg Block': [a_leg_block],
    'Forearms': [a_forearms],
    'Head Block': [a_head_block],
    'Multiplayer': [a_multiplayer],
    'Illegal Contact': [a_illegal_contact],
    'Direction': [a_direction],
    'Illegal Position': [a_illegal_position],
    'Cut': [a_cut],
    'Interference': [a_interference],
    'Illegal Procedure':[a_illegal_procedure],
    'Expulsion': [a_expulsion]


})

a_sums_df = a_sums.transpose()
a_sums_n = a_sums_df.reset_index()
a_sums_n = a_sums_n.rename(columns = {'index': 'penalty', 0: 'count'})
a_sums_c = a_sums_n.sort_values('count')

#Bar chart
a_penalty = a_sums_c['penalty']
count = a_sums_c['count']
x_axis = np.arange(len(a_penalty))

plt.bar(x_axis, count, color='purple', alpha=0.5, align='center')
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, a_penalty, rotation="vertical")

plt.title("Penalty Counts - Alls Only 2019")
plt.xlabel("Penalty")
plt.ylabel("Penalty Count")

plt.savefig("Penalty Counts - Alls Only 2019.png", bbox_inches="tight")

# %%
#OVERALL BRAWLS PENALTIES

b_misconduct = brawls['Misconduct'].sum()
b_high_block = brawls['High Block'].sum()
b_back_block = brawls['Back Block'].sum()
b_low_block = brawls['Low Block'].sum()
b_leg_block = brawls['Leg Block'].sum()
b_forearms = brawls['Forearms'].sum()
b_head_block = brawls['Head Block'].sum()
b_multiplayer = brawls['Multiplayer'].sum()
b_illegal_contact = brawls['Illegal Contact'].sum()
b_direction = brawls['Direction'].sum()
b_illegal_position = brawls['Illegal Position'].sum()
b_cut = brawls['Cut'].sum()
b_interference = brawls['Interference'].sum()
b_illegal_procedure = brawls['Illegal Procedure'].sum()
b_expulsion = brawls['Expulsion'].sum()


b_sums = pd.DataFrame({
    'Misconduct': [b_misconduct],
    'High Block': [b_high_block],
    'Back Block': [b_back_block],
    'Low Block': [b_low_block],
    'Leg Block': [b_leg_block],
    'Forearms': [b_forearms],
    'Head Block': [b_head_block],
    'Multiplayer': [b_multiplayer],
    'Illegal Contact': [b_illegal_contact],
    'Direction': [b_direction],
    'Illegal Position': [b_illegal_position],
    'Cut': [b_cut],
    'Interference': [b_interference],
    'Illegal Procedure':[b_illegal_procedure],
    'Expulsion': [b_expulsion]


})

b_sums_df = b_sums.transpose()
b_sums_n = b_sums_df.reset_index()
b_sums_n = b_sums_n.rename(columns = {'index': 'penalty', 0: 'count'})
b_sums_c = b_sums_n.sort_values('count')

#Bar chart
b_penalty = b_sums_c['penalty']
count = b_sums_c['count']
x_axis = np.arange(len(b_penalty))

plt.bar(x_axis, count, color='magenta', alpha=0.5, align='center')
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, b_penalty, rotation="vertical")

plt.title("Penalty Counts - Brawls Only 2019")
plt.xlabel("Penalty")
plt.ylabel("Penalty Count")

plt.savefig("Penalty Counts - Brawls Only 2019.png", bbox_inches="tight")

# %%
pp_df.head()

# %%
all_j = pp_df.loc[(pp_df['Team']=='All') & (pp_df['#'] == 7) | (pp_df['#'] == 43) | (pp_df['#'] == 53) | (pp_df['#'] == 671) | (pp_df['#'] == 31)]
all_b = pp_df.loc[(pp_df['Team']=='All') & (pp_df['#'] == 11) | (pp_df['#'] == 13) | (pp_df['#'] == 18) | (pp_df['#'] == 23) | (pp_df['#'] == 42) | (pp_df['#'] == 57) | (pp_df['#'] == 64) | (pp_df['#'] == 90) | (pp_df['#'] == 121) | (pp_df['#'] == 124) | (pp_df['#'] == 220) | (pp_df['#'] == 329) | (pp_df['#'] == 777) | (pp_df['#'] == 911) | (pp_df['#'] == 927)]

brawl_j = pp_df.loc[(pp_df['Team']=='Brawl') & (pp_df['JAMMER (# of Jams)']>0)].sum()
brawl_b = pp_df.loc[(pp_df['Team']=='Brawl') & (pp_df['BLOCKER (# of Jams)']>0) & (pp_df['JAMMER (# of Jams)']==0)]

alls_alls = all_b.sum() + all_j.sum()
alls_alls

all_b.sum()
# Out:
# #                                                               3727
# Team                   AllAllAllAllAllAllAllAllAllAllAllAllAllAllAll
# JAMMER (# of Jams)                                               122
# PIVOT (# of Jams)                                                478
# BLOCKER (# of Jams)                                             1653
# Misconduct                                                         6
# High Block                                                        17
# Back Block                                                        21
# Low Block                                                         15
# Leg Block                                                          1
# Forearms                                                          71
# Head Block                                                         0
# Multiplayer                                                       53
# Illegal Contact                                                   16
# ...

# %%
#ALLS JAMMERS

aj_misconduct = all_j['Misconduct'].sum()
aj_high_block = all_j['High Block'].sum()
aj_back_block = all_j['Back Block'].sum()
aj_low_block = all_j['Low Block'].sum()
aj_leg_block = all_j['Leg Block'].sum()
aj_forearms = all_j['Forearms'].sum()
aj_head_block = all_j['Head Block'].sum()
aj_multiplayer = all_j['Multiplayer'].sum()
aj_illegal_contact = all_j['Illegal Contact'].sum()
aj_direction = all_j['Direction'].sum()
aj_illegal_position = all_j['Illegal Position'].sum()
aj_cut = all_j['Cut'].sum()
aj_interference = all_j['Interference'].sum()
aj_illegal_procedure = all_j['Illegal Procedure'].sum()
aj_expulsion = all_j['Expulsion'].sum()


aj_sums = pd.DataFrame({
    'Misconduct': [aj_misconduct],
    'High Block': [aj_high_block],
    'Back Block': [aj_back_block],
    'Low Block': [aj_low_block],
    'Leg Block': [aj_leg_block],
    'Forearms': [aj_forearms],
    'Head Block': [aj_head_block],
    'Multiplayer': [aj_multiplayer],
    'Illegal Contact': [aj_illegal_contact],
    'Direction': [aj_direction],
    'Illegal Position': [aj_illegal_position],
    'Cut': [aj_cut],
    'Interference': [aj_interference],
    'Illegal Procedure':[aj_illegal_procedure],
    'Expulsion': [aj_expulsion]


})

aj_sums_df = aj_sums.transpose()
aj_sums_n = aj_sums_df.reset_index()
aj_sums_n = aj_sums_n.rename(columns = {'index': 'penalty', 0: 'count'})
aj_sums_c = aj_sums_n.sort_values('count')

#Bar chart
aj_penalty = aj_sums_c['penalty']
count = aj_sums_c['count']
x_axis = np.arange(len(aj_penalty))

plt.bar(x_axis, count, color='purple', alpha=0.5, align='center')
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, aj_penalty, rotation="vertical")

plt.title("Penalty Counts - Alls Jammers 2019")
plt.xlabel("Penalty")
plt.ylabel("Penalty Count")

plt.savefig("Penalty Counts - Alls Jammers 2019.png", bbox_inches="tight")

# %%
#ALLS BLOCKERS

ab_misconduct = all_b['Misconduct'].sum()
ab_high_block = all_b['High Block'].sum()
ab_back_block = all_b['Back Block'].sum()
ab_low_block = all_b['Low Block'].sum()
ab_leg_block = all_b['Leg Block'].sum()
ab_forearms = all_b['Forearms'].sum()
ab_head_block = all_b['Head Block'].sum()
ab_multiplayer = all_b['Multiplayer'].sum()
ab_illegal_contact = all_b['Illegal Contact'].sum()
ab_direction = all_b['Direction'].sum()
ab_illegal_position = all_b['Illegal Position'].sum()
ab_cut = all_b['Cut'].sum()
ab_interference = all_b['Interference'].sum()
ab_illegal_procedure = all_b['Illegal Procedure'].sum()
ab_expulsion = all_b['Expulsion'].sum()


ab_sums = pd.DataFrame({
    'Misconduct': [ab_misconduct],
    'High Block': [ab_high_block],
    'Back Block': [ab_back_block],
    'Low Block': [ab_low_block],
    'Leg Block': [ab_leg_block],
    'Forearms': [ab_forearms],
    'Head Block': [ab_head_block],
    'Multiplayer': [ab_multiplayer],
    'Illegal Contact': [ab_illegal_contact],
    'Direction': [ab_direction],
    'Illegal Position': [ab_illegal_position],
    'Cut': [ab_cut],
    'Interference': [ab_interference],
    'Illegal Procedure':[ab_illegal_procedure],
    'Expulsion': [ab_expulsion]


})

ab_sums_df = ab_sums.transpose()
ab_sums_n = ab_sums_df.reset_index()
ab_sums_n = ab_sums_n.rename(columns = {'index': 'penalty', 0: 'count'})
ab_sums_c = ab_sums_n.sort_values('count')

#Bar chart
ab_penalty = ab_sums_c['penalty']
count = ab_sums_c['count']
x_axis = np.arange(len(ab_penalty))

plt.bar(x_axis, count, color='purple', alpha=0.5, align='center')
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ab_penalty, rotation="vertical")

plt.title("Penalty Counts - Alls Blockers 2019")
plt.xlabel("Penalty")
plt.ylabel("Penalty Count")

plt.savefig("Penalty Counts - Alls Blockers 2019.png", bbox_inches="tight")

# %%
#Combined bar chart - Alls JAMMERS next to Alls Overall 

a_penalty = a_sums_c['penalty']
count = a_sums_c['count']
j_count = aj_sums_c['count']
x_axis = np.arange(len(a_penalty))


fig = plt.figure(figsize=(20, 5))
ax = fig.add_subplot(111)

w = 0.3


team = ax.bar(x_axis-w, count, color='purple', alpha=0.5, align='center', width = w)
jammers = ax.bar(x_axis, j_count, color='orange', alpha=0.5, align='center', width = w)


tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, a_penalty, rotation="vertical")

plt.xlim(-1, len(x_axis))

plt.title("Alls Jammers Only and Alls Team Penalties")
ax.set_xlabel("Penalty")
ax.set_ylabel("Penalty Count")

plt.legend((team[0], jammers[0]), ('Alls Team', 'Jammers'))

plt.savefig("Penalty Counts - Alls Jammers Only and Alls Team.png", bbox_inches="tight")

# %%
#Combined bar chart - Alls BLOCKERS next to Alls Overall 

a_penalty = a_sums_c['penalty']
count = a_sums_c['count']
b_count = ab_sums_c['count']
x_axis = np.arange(len(a_penalty))


fig = plt.figure(figsize=(20, 5))
ax = fig.add_subplot(111)

w = 0.3

team = ax.bar(x_axis-w, count, color='purple', alpha=0.5, align='center', width = w)
blockers = ax.bar(x_axis, b_count, color='orange', alpha=0.5, align='center', width = w)


tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, a_penalty, rotation="vertical")

plt.xlim(-1, len(x_axis))

plt.title("Alls Blockers Only and Alls Team Penalties")
ax.set_xlabel("Penalty")
ax.set_ylabel("Penalty Count")

plt.legend((team[0], jammers[0]), ('Alls Team', 'Blockers'))

plt.savefig("Penalty Counts - Alls Blockers Only and Alls Team.png", bbox_inches="tight")
